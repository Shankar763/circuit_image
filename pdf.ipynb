# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankar763/circuit_image/blob/master/pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  from __future__ import absolute_import, division, print_function, unicode_literals

# %%
 import numpy as np

# %%
 import tensorflow as tf

# %%
 from tensorflow import keras as ks

# %%
 print(tf.__version__)
# Out:
# 2.0.0-rc1

# %%
# !pip install tensorflow==2.0-rc1
# Out:
# Requirement already satisfied: tensorflow==2.0-rc1 in /usr/local/lib/python3.6/dist-packages (2.0.0rc1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.11.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (0.9.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.17.5)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (3.10.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (0.34.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.12.0)
# Requirement already satisfied: tb-nightly<1.15.0a20190807,>=1.15.0a20190806 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.15.0a20190806)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (0.1.8)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (0.2.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.1.0)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019080602,>=1.14.0.dev2019080601 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.14.0.dev2019080601)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0-rc1) (1.27.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==2.0-rc1) (45.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0-rc1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.15.0a20190807,>=1.15.0a20190806->tensorflow==2.0-rc1) (3.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0-rc1) (2.8.0)

# %%
  (training_images, training_labels), (test_images, test_labels) = ks.datasets.fashion_mnist.load_data()

# %%
  print('Training Images Dataset Shape:  {}'. format(training_images.shape))
# Out:
# Training Images Dataset Shape:  (60000, 28, 28)

# %%
  print('No. of Training Images Dataset Labels: {}'. format(len(training_labels)))
# Out:
# No. of Training Images Dataset Labels: 60000

# %%
  print('Test Images Dataset Shape: {}'.format(test_images. shape))
# Out:
# Test Images Dataset Shape: (10000, 28, 28)

# %%
  print('No. of Test Images Dataset Labels: {}'. format(len(test_labels)))
# Out:
# No. of Test Images Dataset Labels: 10000

# %%
 training_images = training_images / 255.0

# %%
 test_images = test_images / 255.0

# %%
 input_data_shape = (28, 28)

# %%
 hidden_activation_function = 'relu'

# %%
 output_activation_function = 'softmax'

# %%
from django.db import models
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import datasets, layers, models

# %%
nn_model =models.Sequential()

# %%
  nn_model.add(ks.layers.Flatten(input_shape=input_data_shape, name='Input_layer'))

# %%
  nn_model.add(ks.layers.Dense(32, activation=hidden_activation_function, name='Hidden_layer'))

# %%
  nn_model.add(ks.layers.Dense(10, activation=output_activation_function, name='Output_layer'))

# %%
 nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_layer (Flatten)        (None, 784)               0
# _________________________________________________________________
# Hidden_layer (Dense)         (None, 32)                25120
# _________________________________________________________________
# Output_layer (Dense)         (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
 optimizer = 'adam'

# %%
 loss_function = 'sparse_categorical_crossentropy'

# %%
 metric = ['accuracy']

# %%
  nn_model.compile(optimizer=optimizer, loss=loss_function, metrics=metric)

# %%
 nn_model.fit(training_images, training_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.5511 - accuracy: 0.8094
# Epoch 2/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.4136 - accuracy: 0.8561
# Epoch 3/10
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.3782 - accuracy: 0.8645
# Epoch 4/10
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.3528 - accuracy: 0.8730
# Epoch 5/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.3381 - accuracy: 0.8779
# Epoch 6/10
# 60000/60000 [==============================] - 3s 49us/sample - loss: 0.3248 - accuracy: 0.8822
# Epoch 7/10
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.3153 - accuracy: 0.8849
# Epoch 8/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.3072 - accuracy: 0.8876
# Epoch 9/10
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.3006 - accuracy: 0.8893
# Epoch 10/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.2958 - accuracy: 0.8916

# %%
training_loss, training_accuracy = nn_model. evaluate(training_images, training_labels)
# Out:
# 60000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Training Data Accuracy {}'. format(round(float(training_accuracy),2)))
# Out:
# Training Data Accuracy 0.9

# %%
test_loss, test_accuracy = nn_model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Test Data Accuracy {}'.format(round(float(test_accuracy),2)))
# Out:
# Test Data Accuracy 0.87
